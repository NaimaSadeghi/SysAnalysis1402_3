# %% [markdown]
# <center>
# In the name of God
# <br>
# <h3>System Analysis and Design Course</h3>
#
# <br>
# <img src="Figures/kntu.png" width="50px" height="50px"/>
# <br>
# K. N. Toosi University of Technology
# <br>
#
# </center>

# %% [markdown]
# # Distributions (part 3)

# %% [markdown]
# ## Exponential Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mu=20
val=np.random.exponential(mu,10000000)
count,bins,_=plt.hist(val,bins=100,density=True)
plt.plot((bins[1:]+bins[:-1])/2,count,color="red")
plt.ylabel("f(x)")
plt.xlabel("x")
plt.title("Exponential PDF")
# Out:
# Text(0.5, 1.0, 'Exponential PDF')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# plot the expected number of remaining molecules respect to time
import random
p=.005 # probability of molecule to be destroyed
n=100000
remain=n 
time=0
values=[remain]
times=[0]
while remain>0:
    time+=1
    for i in range(remain):
        if random.random()<=p:
            remain-=1
    values.append(remain)
    times.append(time) 
    time+=1
plt.plot(values,times)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
##Class exe.
# Out:
# (array([7.0080e+04, 2.9509e+04, 2.0439e+04, 1.4134e+04, 9.8240e+03,
#         6.9630e+03, 6.5800e+03, 2.7830e+03, 1.8360e+03, 1.3660e+03,
#         8.8400e+02, 6.7500e+02, 4.5500e+02, 4.5400e+02, 1.7200e+02,
#         1.1800e+02, 8.3000e+01, 5.8000e+01, 2.9000e+01, 3.3000e+01,
#         1.7000e+01, 1.0000e+01, 5.0000e+00, 5.0000e+00, 6.0000e+00,
#         4.0000e+00, 3.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([ 1.  ,  3.15,  5.3 ,  7.45,  9.6 , 11.75, 13.9 , 16.05, 18.2 ,
#         20.35, 22.5 , 24.65, 26.8 , 28.95, 31.1 , 33.25, 35.4 , 37.55,
#         39.7 , 41.85, 44.  , 46.15, 48.3 , 50.45, 52.6 , 54.75, 56.9 ,
#         59.05, 61.2 , 63.35, 65.5 , 67.65, 69.8 , 71.95, 74.1 , 76.25,
#         78.4 , 80.55, 82.7 , 84.85, 87.  ]),
#  <BarContainer object of 40 artists>)

# %% [markdown]
# <img src="Figures/expo.png" width="500px" />

# %% [markdown]
# <img src="Figures/memoryless.png" width="500px" />

# %% [markdown]
# <img src="Figures/memoryless_formula.png" width="500px" />

# %% [markdown]
# ## Poisson distribution

# %% [markdown]
# <img src="Figures/poisson.png" width="500px" />

# %% [markdown]
# ## Beta distribution
# <img src="Figures/beta_pdf.png" width="500px" />

# %%
l=4
h=10
vals=np.random.beta(6,17,100000)*6+4
a=plt.hist(vals,density=True,bins=100)
