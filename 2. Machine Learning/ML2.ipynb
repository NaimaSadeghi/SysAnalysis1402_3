# %%
import pandas as pd

# %%
df=pd.read_csv("FuelConsumption.csv")
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0             AS5        Z                   9.9                  6.7
# 1              M6        Z                  11.2                  7.7
# 2             AV7        Z                   6.0                  5.8
# 3             AS6        Z                  12.7                  9.1
# 4             AS6        Z                  12.1                  8.7
# ...           ...      ...                   ...                  ...
# 1062          AS6        X                  13.4                  9.8
# 1063          AS6        X                  13.2                  9.5
# 1064          AS6        X                  13.4                  9.8
# 1065          AS6        X                  12.9                  9.3
# 1066          AS6        X                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1067 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
train,test=train_test_split(df,test_size=.2,random_state=52)
# Out:
#      MODELYEAR        MAKE                            MODEL  \
# 376       2014        FORD                         F150 FFV
# 92        2014         BMW                       428i COUPE
# 845       2014      NISSAN                             JUKE
# 220       2014   CHEVROLET           EXPRESS 1500 PASSENGER
# 648       2014  LAND ROVER  RANGE ROVER SPORT V8 5.0 SC FFV
# ..         ...         ...                              ...
# 905       2014     PORSCHE                     PANAMERA GTS
# 964       2014      SUBARU          XV CROSSTREK HYBRID AWD
# 209       2014   CHEVROLET                      EQUINOX AWD
# 489       2014       HONDA                            CIVIC
# 358       2014        FORD                           ESCAPE
#
#                 VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 376  PICKUP TRUCK - STANDARD         3.7          6           A6        E
# 92                   COMPACT         2.0          4           M6        Z
# 845    STATION WAGON - SMALL         1.6          4           AV        Z
# 220          VAN - PASSENGER         5.3          8           A4        E
# 648           SUV - STANDARD         5.0          8          AS8        E
# ..                       ...         ...        ...          ...      ...
# 905                FULL-SIZE         4.8          8          AM7        Z
# 964              SUV - SMALL         2.0          4           AV        X
# 209              SUV - SMALL         3.6          6           A6        E
# 489                  COMPACT         1.8          4          AV7        X
# 358              SUV - SMALL         2.5          4          AS6        X
#
#      FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 376                  18.8                 13.7                  16.5
# 92                   10.4                  6.7                   8.7
# 845                   8.7                  7.3                   8.1
# 220                  23.9                 18.5                  21.5
# 648                  24.0                 16.6                  20.7
# ..                    ...                  ...                   ...
# 905                  15.1                  9.7                  12.7
# 964                   8.1                  7.2                   7.7
# 209                  19.8                 13.6                  17.0
# 489                   8.1                  6.2                   7.2
# 358                  10.9                  7.5                   9.4
#
#      FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 376                        17           264
# 92                         32           200
# 845                        35           186
# 220                        13           344
# 648                        14           331
# ..                        ...           ...
# 905                        22           292
# 964                        37           177
# 209                        17           272
# 489                        39           166
# 358                        30           216
#
# [214 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 108.5+ KB

# %%
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# 25%               7.500000              9.000000                 21.000000
# 50%               8.800000             10.900000                 26.000000
# 75%              10.850000             13.350000                 31.000000
# max              20.500000             25.800000                 60.000000
#
#        CO2EMISSIONS
# count   1067.000000
# mean     256.228679
# std       63.372304
# min      108.000000
# 25%      207.000000
# 50%      251.000000
# 75%      294.000000
# max      488.000000

# %%
df["MODELYEAR"]=pd.to_numeric(df["MODELYEAR"])
x_train=train[["ENGINESIZE","CYLINDERS","FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB","FUELCONSUMPTION_COMB_MPG"]]
y_train=train["CO2EMISSIONS"]
x_train.describe()
# Out:
#        ENGINESIZE   CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# count  853.000000  853.000000            853.000000           853.000000
# mean     3.361313    5.808910             13.343494             9.503400
# std      1.421557    1.815379              4.136590             2.793222
# min      1.000000    3.000000              4.700000             4.900000
# 25%      2.000000    4.000000             10.300000             7.500000
# 50%      3.400000    6.000000             12.700000             8.800000
# 75%      4.200000    8.000000             15.400000            10.700000
# max      8.400000   12.000000             30.200000            20.500000
#
#        FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG
# count            853.000000                853.000000
# mean              11.619930                 26.348183
# std                3.503386                  7.404762
# min                4.800000                 11.000000
# 25%                9.100000                 21.000000
# 50%               11.000000                 26.000000
# 75%               13.300000                 31.000000
# max               25.800000                 59.000000

# %%
x_train.corr(numeric_only=False)
# Out:
#                           ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  \
# ENGINESIZE                  1.000000   0.930490              0.828479
# CYLINDERS                   0.930490   1.000000              0.792596
# FUELCONSUMPTION_CITY        0.828479   0.792596              1.000000
# FUELCONSUMPTION_HWY         0.771273   0.714016              0.965182
# FUELCONSUMPTION_COMB        0.814600   0.770729              0.995532
# FUELCONSUMPTION_COMB_MPG   -0.806109  -0.768381             -0.934037
#
#                           FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# ENGINESIZE                           0.771273              0.814600
# CYLINDERS                            0.714016              0.770729
# FUELCONSUMPTION_CITY                 0.965182              0.995532
# FUELCONSUMPTION_HWY                  1.000000              0.985476
# FUELCONSUMPTION_COMB                 0.985476              1.000000
# FUELCONSUMPTION_COMB_MPG            -0.891844             -0.926368
#
#                           FUELCONSUMPTION_COMB_MPG
# ENGINESIZE                               -0.806109
# CYLINDERS                                -0.768381
# FUELCONSUMPTION_CITY                     -0.934037
# FUELCONSUMPTION_HWY                      -0.891844
# FUELCONSUMPTION_COMB                     -0.926368
# FUELCONSUMPTION_COMB_MPG                  1.000000

# %%
x_train.corrwith(y_train)
# Out:
# ENGINESIZE                  0.874760
# CYLINDERS                   0.851905
# FUELCONSUMPTION_CITY        0.897929
# FUELCONSUMPTION_HWY         0.856827
# FUELCONSUMPTION_COMB        0.890452
# FUELCONSUMPTION_COMB_MPG   -0.909171
# dtype: float64

# %%
x_train=train[["ENGINESIZE","CYLINDERS","FUELCONSUMPTION_COMB"]]
x_test=test[["ENGINESIZE","CYLINDERS","FUELCONSUMPTION_COMB"]]
y_test=test["CO2EMISSIONS"]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([10.33915928,  8.07207334,  9.31643206])

# %%
model.intercept_
# Out:
# 67.03731279061267

# %%
from sklearn.metrics import mean_squared_error
y_train_=model.predict(x_train)
mse=mean_squared_error(y_train,y_train_)
print("rmse on train data is:",mse**.5)
# Out:
# rmse on train data is: 22.92350684655023

# %%
from sklearn.metrics import mean_squared_error
y_test_=model.predict(x_test)
mse=mean_squared_error(y_test,y_test_)
print("rmse on test data is:",mse**.5)
# Out:
# rmse on test data is: 25.10083274818758

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_test_)
# Out:
# 0.8535332480244222
